# %% [markdown]
# <a href="https://colab.research.google.com/github/kpomal/Btecky/blob/main/Data_Analysis_and_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/Viral_Social_Media_Trends.csv")

# %%
df
# Out:
#         Post_ID   Platform     Hashtag Content_Type     Region    Views  \
# 0        Post_1     TikTok  #Challenge        Video         UK  4163464
# 1        Post_2  Instagram  #Education       Shorts      India  4155940
# 2        Post_3    Twitter  #Challenge        Video     Brazil  3666211
# 3        Post_4    YouTube  #Education       Shorts  Australia   917951
# 4        Post_5     TikTok      #Dance         Post     Brazil    64866
# ...         ...        ...         ...          ...        ...      ...
# 4995  Post_4996    YouTube  #Education        Video      Japan  4258236
# 4996  Post_4997  Instagram  #Education        Video         UK  4841525
# 4997  Post_4998    YouTube    #Fashion       Shorts        USA  2004080
# 4998  Post_4999  Instagram     #Gaming       Shorts     Canada  2221665
# 4999  Post_5000  Instagram    #Fashion         Reel      Japan  2224007
#
#        Likes  Shares  Comments Engagement_Level
# 0     339431   53135     19346             High
# ...

# %%
df.head(10)
# Out:
#    Post_ID   Platform     Hashtag Content_Type     Region    Views   Likes  \
# 0   Post_1     TikTok  #Challenge        Video         UK  4163464  339431
# 1   Post_2  Instagram  #Education       Shorts      India  4155940  215240
# 2   Post_3    Twitter  #Challenge        Video     Brazil  3666211  327143
# 3   Post_4    YouTube  #Education       Shorts  Australia   917951  127125
# 4   Post_5     TikTok      #Dance         Post     Brazil    64866  171361
# 5   Post_6  Instagram  #Challenge       Shorts  Australia  1323566  136282
# 6   Post_7    YouTube     #Comedy        Tweet      Japan   627233   84121
# 7   Post_8    YouTube     #Gaming       Shorts         UK  2066886  317502
# 8   Post_9    Twitter  #Education  Live Stream      India  2169523  496078
# 9  Post_10     TikTok     #Gaming       Shorts      India  3898384    8634
#
#    Shares  Comments Engagement_Level
# 0   53135     19346             High
# 1   65860     27239           Medium
# ...

# %%
df.tail(10)
# Out:
#         Post_ID   Platform     Hashtag Content_Type     Region    Views  \
# 4990  Post_4991    YouTube      #Viral         Reel  Australia  4989926
# 4991  Post_4992  Instagram    #Fashion       Shorts     Brazil    10157
# 4992  Post_4993    Twitter      #Viral        Tweet     Brazil  2026985
# 4993  Post_4994    YouTube  #Education        Tweet        USA  3515254
# 4994  Post_4995  Instagram     #Comedy       Shorts     Brazil   940934
# 4995  Post_4996    YouTube  #Education        Video      Japan  4258236
# 4996  Post_4997  Instagram  #Education        Video         UK  4841525
# 4997  Post_4998    YouTube    #Fashion       Shorts        USA  2004080
# 4998  Post_4999  Instagram     #Gaming       Shorts     Canada  2221665
# 4999  Post_5000  Instagram    #Fashion         Reel      Japan  2224007
#
#        Likes  Shares  Comments Engagement_Level
# 4990  393298   99274     29395              Low
# 4991  322897   93292     23766             High
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Post_ID           5000 non-null   object
#  1   Platform          5000 non-null   object
#  2   Hashtag           5000 non-null   object
#  3   Content_Type      5000 non-null   object
#  4   Region            5000 non-null   object
#  5   Views             5000 non-null   int64
#  6   Likes             5000 non-null   int64
#  7   Shares            5000 non-null   int64
#  8   Comments          5000 non-null   int64
#  9   Engagement_Level  5000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 390.8+ KB

# %%
x= df[['Platform', 'Views', 'Likes']]

# %%
df[['Platform','Views']]
# Out:
#        Platform    Views
# 0        TikTok  4163464
# 1     Instagram  4155940
# 2       Twitter  3666211
# 3       YouTube   917951
# 4        TikTok    64866
# ...         ...      ...
# 4995    YouTube  4258236
# 4996  Instagram  4841525
# 4997    YouTube  2004080
# 4998  Instagram  2221665
# 4999  Instagram  2224007
#
# [5000 rows x 2 columns]

# %%
x
# Out:
#        Platform    Views   Likes
# 0        TikTok  4163464  339431
# 1     Instagram  4155940  215240
# 2       Twitter  3666211  327143
# 3       YouTube   917951  127125
# 4        TikTok    64866  171361
# ...         ...      ...     ...
# 4995    YouTube  4258236  381509
# 4996  Instagram  4841525  166266
# 4997    YouTube  2004080   32401
# 4998  Instagram  2221665   46996
# 4999  Instagram  2224007   72744
#
# [5000 rows x 3 columns]

# %%
x.describe()
# Out:
#               Views          Likes
# count  5.000000e+03    5000.000000
# mean   2.494066e+06  251475.029800
# std    1.459490e+06  144349.583384
# min    1.266000e+03     490.000000
# 25%    1.186207e+06  126892.250000
# 50%    2.497373e+06  249443.000000
# 75%    3.759781e+06  373970.750000
# max    4.999430e+06  499922.000000

# %%
df.isnull().sum()
# Out:
# Post_ID             0
# Platform            0
# Hashtag             0
# Content_Type        0
# Region              0
# Views               0
# Likes               0
# Shares              0
# Comments            0
# Engagement_Level    0
# dtype: int64

# %%
#let's say there are missing values in sales columns

df['Views_new'] = df['Views'].fillna(0)

#let's say there are missing values in sales columns through median

df['Views_new'] = df['Views'].fillna(df['Views'].median())

# %%
df['Views'].median()
# Out:
# 2497373.0

# %%
import seaborn as sbn

# %%
sbn.countplot(x='Platform', data= df)
# Out:
# <Axes: xlabel='Platform', ylabel='count'>

# %%
sbn.scatterplot(x='Platform', y='Content_Type', data=df, hue='Region')
# Out:
# <Axes: xlabel='Platform', ylabel='Content_Type'>

# %%
df.groupby(["Region"])['Shares'].mean()
# Out:
# Region
# Australia    50790.504983
# Brazil       50675.541342
# Canada       50455.468085
# Germany      49170.302120
# India        50328.191248
# Japan        51566.586149
# UK           50462.619784
# USA          50634.545052
# Name: Shares, dtype: float64

# %%
df.groupby(["Platform"])['Shares'].mean().sort_values(ascending=False)
# Out:
# Platform
# TikTok       51468.256349
# Instagram    50310.909241
# Twitter      50227.750831
# YouTube      50073.091390
# Name: Shares, dtype: float64

# %%
df.groupby(["Platform"])['Shares'].mean().sort_values(ascending=True).tail(1)
# Out:
# Platform
# TikTok    51468.256349
# Name: Shares, dtype: float64

# %%
df.groupby(["Platform"])['Shares'].mean().sort_values(ascending=False).head(1)
# Out:
# Platform
# TikTok    51468.256349
# Name: Shares, dtype: float64

# %%
df.groupby('Platform')['Shares'].sum().sort_values(ascending=False).head(1)
# Out:
# Platform
# YouTube    66296773
# Name: Shares, dtype: int64

# %%
df.shape
# Out:
# (5000, 11)

# %%
df[df['Shares']>50]
# Out:
#         Post_ID   Platform     Hashtag Content_Type     Region    Views  \
# 0        Post_1     TikTok  #Challenge        Video         UK  4163464
# 1        Post_2  Instagram  #Education       Shorts      India  4155940
# 2        Post_3    Twitter  #Challenge        Video     Brazil  3666211
# 3        Post_4    YouTube  #Education       Shorts  Australia   917951
# 4        Post_5     TikTok      #Dance         Post     Brazil    64866
# ...         ...        ...         ...          ...        ...      ...
# 4995  Post_4996    YouTube  #Education        Video      Japan  4258236
# 4996  Post_4997  Instagram  #Education        Video         UK  4841525
# 4997  Post_4998    YouTube    #Fashion       Shorts        USA  2004080
# 4998  Post_4999  Instagram     #Gaming       Shorts     Canada  2221665
# 4999  Post_5000  Instagram    #Fashion         Reel      Japan  2224007
#
#        Likes  Shares  Comments Engagement_Level  Views_new
# ...

# %%
df[df['Shares']>50].shape
# Out:
# (5000, 11)

# %%
x #subset
# Out:
#        Platform    Views   Likes
# 0        TikTok  4163464  339431
# 1     Instagram  4155940  215240
# 2       Twitter  3666211  327143
# 3       YouTube   917951  127125
# 4        TikTok    64866  171361
# ...         ...      ...     ...
# 4995    YouTube  4258236  381509
# 4996  Instagram  4841525  166266
# 4997    YouTube  2004080   32401
# 4998  Instagram  2221665   46996
# 4999  Instagram  2224007   72744
#
# [5000 rows x 3 columns]

# %%
x= df[['Platform', 'Views', 'Likes', 'Shares']]

# %%
sbn.pairplot(x, hue='Views')
